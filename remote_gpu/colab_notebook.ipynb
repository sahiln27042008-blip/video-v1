# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# Video Brain Remote GPU Worker\n",
    "Run all cells in order. This notebook will start a GPU worker with a public URL."
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "!pip install -q fastapi uvicorn pyngrok cloudflared requests python-multipart\n",
    "!pip install -q pyscenedetect opencv-python insightface onnxruntime pydantic typer rich\n",
    "!pip install -q whisperx torch torchaudio huggingface-hub scikit-learn\n",
    "!pip install -q scenedetect python-dotenv"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "import os\n",
    "# Set your HF token here or create a .env file\n",
    "os.environ['HF_TOKEN'] = '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'"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Upload the remote_gpu folder to Colab first, then run this\n",
    "!python remote_gpu/start_colab.py"
   ]
  }
 ],
 "metadata": {
  "accelerator": "GPU",
  "colab": {
   "provenance": []
  },
  "kernelspec": {
   "display_name": "Python 3",
   "name": "python3"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 0
}
